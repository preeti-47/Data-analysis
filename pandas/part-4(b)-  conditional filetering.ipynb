# %%
import pandas as pd

# %%
path = ('/home/preeti/Desktop/pandas/data/survey_results_public.csv')
schema_path = ('/home/preeti/Desktop/pandas/data/survey_results_schema.csv')

# %%
df = pd.read_csv(path)
schema_df = pd.read_csv(schema_path)

# %%
# pd.set_option('display.max_columns',85)
# pd.set_option('display.max_rows', 85)

# %%
df.head()
list(df.columns)  #to print column name
# Out:
# ['ResponseId',
#  'MainBranch',
#  'Employment',
#  'RemoteWork',
#  'CodingActivities',
#  'EdLevel',
#  'LearnCode',
#  'LearnCodeOnline',
#  'LearnCodeCoursesCert',
#  'YearsCode',
#  'YearsCodePro',
#  'DevType',
#  'OrgSize',
#  'PurchaseInfluence',
#  'BuyNewTool',
#  'Country',
#  'Currency',
#  'CompTotal',
#  'CompFreq',
#  'LanguageHaveWorkedWith',
#  'LanguageWantToWorkWith',
#  'DatabaseHaveWorkedWith',
#  'DatabaseWantToWorkWith',
#  'PlatformHaveWorkedWith',
#  'PlatformWantToWorkWith',
#  'WebframeHaveWorkedWith',
#  'WebframeWantToWorkWith',
#  'MiscTechHaveWorkedWith',
#  'MiscTechWantToWorkWith',
#  'ToolsTechHaveWorkedWith',
#  'ToolsTechWantToWorkWith',
#  'NEWCollabToolsHaveWorkedWith',
#  'NEWCollabToolsWantToWorkWith',
#  'OpSysProfessional use',
#  'OpSysPersonal use',
#  'VersionControlSystem',
#  'VCInteraction',
#  'VCHostingPersonal use',
#  'VCHostingProfessional use',
#  'OfficeStackAsyncHaveWorkedWith',
#  'OfficeStackAsyncWantToWorkWith',
# ...

# %%
# iterating the columns
for col in df.columns:   
    print(col)
# Out:
# ResponseId
# MainBranch
# Employment
# RemoteWork
# CodingActivities
# EdLevel
# LearnCode
# LearnCodeOnline
# LearnCodeCoursesCert
# YearsCode
# YearsCodePro
# DevType
# OrgSize
# PurchaseInfluence
# BuyNewTool
# Country
# Currency
# CompTotal
# CompFreq
# LanguageHaveWorkedWith
# LanguageWantToWorkWith
# DatabaseHaveWorkedWith
# DatabaseWantToWorkWith
# PlatformHaveWorkedWith
# PlatformWantToWorkWith
# WebframeHaveWorkedWith
# WebframeWantToWorkWith
# MiscTechHaveWorkedWith
# MiscTechWantToWorkWith
# ToolsTechHaveWorkedWith
# ToolsTechWantToWorkWith
# NEWCollabToolsHaveWorkedWith
# NEWCollabToolsWantToWorkWith
# OpSysProfessional use
# OpSysPersonal use
# VersionControlSystem
# VCInteraction
# VCHostingPersonal use
# VCHostingProfessional use
# OfficeStackAsyncHaveWorkedWith
# OfficeStackAsyncWantToWorkWith
# OfficeStackSyncHaveWorkedWith
# OfficeStackSyncWantToWorkWith
# Blockchain
# NEWSOSites
# SOVisitFreq
# SOAccount
# SOPartFreq
# SOComm
# Age
# Gender
# Trans
# Sexuality
# ...

# %%
#filter example
high_salary =(df['ConvertedCompYearly'] > 70000)

# %%
df.loc[high_salary]
df.loc[high_salary, ['Employment','RemoteWork','MainBranch']]
# Out:
#                                               Employment  \
# 3                                    Employed, full-time
# 11     Employed, full-time;Independent contractor, fr...
# 14     Employed, full-time;Independent contractor, fr...
# 17                                   Employed, full-time
# 22                                   Employed, full-time
# ...                                                  ...
# 73107                                Employed, full-time
# 73111                                Employed, full-time
# 73113                                Employed, full-time
# 73116                                Employed, full-time
# 73121                                Employed, full-time
#
#                                  RemoteWork  \
# 3                              Fully remote
# 11                             Fully remote
# 14                             Fully remote
# 17                             Fully remote
# 22                             Fully remote
# ...

# %%
# filter multiple values
countries = ['India','United States','United kingdom','Germany','Cananda']
filt = df['Country'].isin(countries)

# %%
df.loc[filt,'Country']
# Out:
# 5        Germany
# 6          India
# 7          India
# 25       Germany
# 48       Germany
#           ...
# 73247    Germany
# 73255      India
# 73257      India
# 73258      India
# 73262    Germany
# Name: Country, Length: 12034, dtype: object

# %%
#filter strings
filt_str = df['Employment'].str.contains('Employed', na=False)
# filt_str
# df.loc[filt_str, 'Employment']

# %%
df.loc[filt_str, 'Employment']
# Out:
# 1                           Employed, full-time
# 2                           Employed, full-time
# 3                           Employed, full-time
# 4                           Employed, full-time
# 8                           Employed, full-time
#                           ...
# 73262    Student, full-time;Employed, part-time
# 73263                       Employed, full-time
# 73264                       Employed, full-time
# 73265                       Employed, full-time
# 73266                       Employed, full-time
# Name: Employment, Length: 52834, dtype: object
